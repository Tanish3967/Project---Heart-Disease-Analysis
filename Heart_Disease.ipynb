# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')

# %%
df.head(3)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
new_var = sns.displot(df['Age'], kde = True, color = "green", edgecolor = "Red")
new_var

# %%
sns.distplot(df['Age'], color="green", hist=False, rug=True)
plt.show()
# Out:
# <ipython-input-4-2b0a6c82aae0>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], color="green", hist=False, rug=True)

# %%
sns.displot(df['Age'], color="green", bins = 100, kde = True)
plt.show()

# %%
sns.displot(df['Age'], color="blue", kde = True, bins = 50)
plt.show()

# %%
sns.displot(df['RestingBP'], color="blue", kde = True)# bins = 50)
plt.show()

# %%
sns.distplot(df['RestingBP'], color="green", hist=False, rug=True)
plt.show()
# Out:
# <ipython-input-21-3f1089c66e04>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['RestingBP'], color="green", hist=False, rug=True)

# %%
sns.histplot(df["Cholesterol"], kde = False, color = "blue", edgecolor = "Black")
plt.show()

# %%
sns.distplot(df["FastingBS"], kde = True)
# Out:
# <ipython-input-37-a3ffda7fb99d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["FastingBS"], kde = True)
# <Axes: xlabel='FastingBS', ylabel='Density'>

# %%
sns.distplot(df["MaxHR"], kde = True)
# Out:
# <ipython-input-47-fc59124a7ca9>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["MaxHR"], kde = True)
# <Axes: xlabel='MaxHR', ylabel='Density'>

# %%
sns.distplot(df["Oldpeak"], kde = True)
# Out:
# <ipython-input-49-398b2b74e5bb>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Oldpeak"], kde = True)
# <Axes: xlabel='Oldpeak', ylabel='Density'>

# %%
df.groupby('Sex').size().plot(kind = 'pie', autopct = "%.1f%%", legend = True, figsize = (2,2))
plt.show()

# %%
df.groupby('RestingECG').size().plot(kind = 'pie', autopct = "%.1f%%", legend = False, title = "ECG", figsize = (2,2))
# Out:
# <Axes: title={'center': 'ECG'}>

# %%
df.groupby("ST_Slope").size().plot(kind = "bar")
# Out:
# <Axes: xlabel='ST_Slope'>

# %%
df.groupby("HeartDisease").size().plot(kind = "bar")
# Out:
# <Axes: xlabel='HeartDisease'>

# %%
mean_bp = df[df['RestingBP'] != 0]['RestingBP'].mean()
df['RestingBP'] = df['RestingBP'].replace(0, mean_bp)

df.groupby("Age")["RestingBP"].mean().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Age'>

# %%
sns.violinplot(x = "HeartDisease", y = "Age", hue = "Cholesterol", data = df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
z = df.select_dtypes(include = 'number').corr()

# %%
sns.heatmap(z, annot = True)
# Out:
# <Axes: >

# %%
sns.jointplot(x = "Age", y = "MaxHR", data = df)

# %%
sns.jointplot(x = "HeartDisease", y = "Oldpeak", data = df)

# %%
sns.jointplot(x = "Cholesterol", y = "Oldpeak", data = df, color = "pink")

# %%
sns.jointplot(x = "Age", y = "MaxHR", data = df, color = "beige", kind = "hex")

# %%
sns.jointplot(x = "Age", y = "MaxHR", data = df, color = "beige", kind = "reg")

# %%
sns.jointplot(x = "Cholesterol", y = "FastingBS", data = df, color = "blue", kind = "reg")

# %%
sns.jointplot(x = "HeartDisease", y = "MaxHR", data = df, color = "blue", kind = "reg")

# %%
sns.jointplot(x = "Cholesterol", y = "MaxHR", data = df, color = "violet", kind = "reg")

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue = "HeartDisease")

# %%
sns.pairplot(df, hue="HeartDisease", vars=["Age"]) # Use 'vars' to specify a subset of variables to plot against each other.
